# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_tour = pd.read_csv('data/destinations.csv', encoding='ISO-8859-1')
df_media = pd.read_csv('data/tmdb_popular.csv')

# %%
# Out:
# C:\Users\Thiago\AppData\Local\Temp\ipykernel_18288\1107008174.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(comp.index, rotation=45, ha='right')
